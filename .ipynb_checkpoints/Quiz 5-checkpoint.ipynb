# %% [markdown]
# # Quiz 5
# Please follow the directions below, in which you will extract data from an off-line source and migrate it into a normalized SQLite database. Points will be awarded as indicated. Note: later steps depend on earlier steps, so you should check your work as you go along.
#
# __All required cells have been provided. You only need to edit the ones that have placeholder phrases like YOUR CODE HERE.__
#
# This quiz is open book. You may use whatever documentation you like (even Google or past assignments in the course) but **you may not consult another person during the quiz** without the instructor's permission. That includes sharing code with your classmates, which is obviously not allowed.
#
# __Finally, use comments to document what you are doing with each block of code. Poorly documented code will be penalized accordingly.__

# %% [markdown]
# ## 1. (4 points) Import/Load all required packages.
# Import `pandas`, `sqlite3`, and the `parse_course_spec()` function from [`coursedata-util.py`](coursedata_util.py). (Hint: you may want to take a look at how we imported custom module code in the Movies Tonight Part 5 demo.) Then load the `sql` Jupyter extention needed for `%sql` magic.

# %%
import sqlite3
import pandas as pd
from coursedata_util import parse_course_spec
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ## 2. (1 point) Create a SQLite database named `FairfieldCoursesFall2017.db`.

# %%
# %sql sqlite:///FairfieldCoursesFall2017.db
# Out:
# 'Connected: None@FairfieldCoursesFall2017.db'

# %% [markdown]
# ## 3. (8 points) Study the source data and design your database.
# The [`CourseScheduleScrape.txt` file](CourseScheduleScrape.txt) located in this folder was *scraped* directly from the PDF of the [Fall 2016 Schedule of Courses](Fall2015_course_booklet.pdf) booklet. The code cell below *parses* each line of the file into a `list` of `dict`s called `course_specs`. The result looks a lot like [JSON-formatted data](https://www.ibm.com/support/knowledgecenter/en/STXNRM_3.10.2/coss.doc/managerapi1128.html) commonly returned by ReSTful web services. You will need to extract the data into tables in a SQLite database.

# %%
# DO NOT EDIT THIS CELL
course_specs = []
for spec in open("CourseScheduleScrape.txt").read().splitlines():
    course_specs.append(parse_course_spec(spec))
course_specs
# Out:
# [{'CRN': '76407',
#   'CatalogID': 'AS0200',
#   'Credits': '3',
#   'Instructor': 'Bayers P',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Roots of American Culture'},
#  {'CRN': '76513',
#   'CatalogID': 'AS0400',
#   'Credits': '3',
#   'Instructor': 'Garvey J',
#   'Section': '01',
#   'Tags': ['By Permission'],
#   'Timecodes': ['W 0630-0830pm'],
#   'Title': 'Critical Issues/Amer Studies'},
#  {'CRN': '76934',
#   'CatalogID': 'AS0488',
#   'Credits': '3',
#   'Instructor': 'Bayers P',
#   'Section': '01',
#   'Tags': ['By Permission'],
#   'Timecodes': ['M 0630-0830pm'],
#   'Title': 'Frontier in American Culture'},
#  {'CRN': '76935',
#   'CatalogID': 'ASEN0490',
#   'Credits': '3',
#   'Instructor': 'Lopez E',
#   'Section': '01',
#   'Tags': ['By Permission'],
#   'Timecodes': ['T 0545-0745pm'],
#   'Title': 'Contemporary American Memoir'},
#  {'CRN': '75478',
#   'CatalogID': 'AY0010',
#   'Credits': '3',
#   'Instructor': 'Lacy S',
#   'Section': 'C01',
#   'Tags': ['CRNST', 'WDiv'],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Intro to Four-Field Anthropo'},
#  {'CRN': '75479',
#   'CatalogID': 'AY0010',
#   'Credits': '3',
#   'Instructor': 'Lacy S',
#   'Section': 'C02',
#   'Tags': ['CRNST', 'WDiv'],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Intro to Four-Field Anthropo'},
#  {'CRN': '75752',
#   'CatalogID': 'AY0052',
#   'Credits': '3',
#   'Instructor': 'Crawford D',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TR 0630-0745pm'],
#   'Title': 'Culture and Political Economy'},
#  {'CRN': '76300',
#   'CatalogID': 'AY0052',
#   'Credits': '3',
#   'Instructor': 'Wilson J',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Culture and Political Economy'},
#  {'CRN': '75297',
#   'CatalogID': 'AY0110',
#   'Credits': '3',
#   'Instructor': 'Wilson J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Biological Anthropology'},
#  {'CRN': '75728',
#   'CatalogID': 'AY0111',
#   'Credits': '3',
#   'Instructor': 'Crawford D',
#   'Section': 'A',
#   'Tags': ['WDiv'],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Cultural Anthropology'},
#  {'CRN': '76753',
#   'CatalogID': 'AY0111',
#   'Credits': '3',
#   'Instructor': 'Wessler S',
#   'Section': 'B',
#   'Tags': ['WDiv'],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Cultural Anthropology'},
#  {'CRN': '76758',
#   'CatalogID': 'AY0115',
#   'Credits': '3',
#   'Instructor': 'Aronsen G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Biomedical Anthropology'},
#  {'CRN': '76303',
#   'CatalogID': 'AY0152',
#   'Credits': '3',
#   'Instructor': 'Crawford D',
#   'Section': 'A',
#   'Tags': ['WDiv', 'ResColl'],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Islamic Societies & Cultures'},
#  {'CRN': '76754',
#   'CatalogID': 'AY0168',
#   'Credits': '3',
#   'Instructor': 'Wessler S',
#   'Section': 'A',
#   'Tags': ['WDiv'],
#   'Timecodes': ['TF 0330-0445pm'],
#   'Title': 'Women & Men: Anthro of Gender'},
#  {'CRN': '75333',
#   'CatalogID': 'AE0262',
#   'Credits': '3',
#   'Instructor': 'Liftig R',
#   'Section': 'A',
#   'Tags': ['USDiv'],
#   'Timecodes': ['W 0200-0430pm'],
#   'Title': 'Ethics and the Community'},
#  {'CRN': '75233',
#   'CatalogID': 'AE0265',
#   'Credits': '3',
#   'Instructor': 'Liftig R',
#   'Section': 'A',
#   'Tags': ['USDiv'],
#   'Timecodes': ['TR 0500-0615pm'],
#   'Title': 'Ethics in Education'},
#  {'CRN': '75282',
#   'CatalogID': 'AE0276',
#   'Credits': '3',
#   'Instructor': 'Day R',
#   'Section': 'A',
#   'Tags': ['WDiv'],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Ethical DimensGlobal BusPolicy'},
#  {'CRN': '76234',
#   'CatalogID': 'AE0281',
#   'Credits': '3',
#   'Instructor': 'Butler B',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Ethics of Communications'},
#  {'CRN': '76826',
#   'CatalogID': 'AE0284',
#   'Credits': '3',
#   'Instructor': 'Brown D',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['WF 0800-0915am'],
#   'Title': 'Environmental Ethics'},
#  {'CRN': '75125',
#   'CatalogID': 'AE0284',
#   'Credits': '3',
#   'Instructor': 'Brown D',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['R 0630-0900pm'],
#   'Title': 'Environmental Ethics'},
#  {'CRN': '75001',
#   'CatalogID': 'AE0285',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MW 0500-0615pm'],
#   'Title': 'Ethics of Health Care'},
#  {'CRN': '75002',
#   'CatalogID': 'AE0291',
#   'Credits': '3',
#   'Instructor': 'Schmidt D',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Business Ethics'},
#  {'CRN': '75003',
#   'CatalogID': 'AE0291',
#   'Credits': '3',
#   'Instructor': 'Sticca-Conrod L',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['Online'],
#   'Title': 'Business Ethics'},
#  {'CRN': '75070',
#   'CatalogID': 'AE0291',
#   'Credits': '3',
#   'Instructor': 'Sticca-Conrod L',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['Online'],
#   'Title': 'Business Ethics'},
#  {'CRN': '75308',
#   'CatalogID': 'AE0291',
#   'Credits': '3',
#   'Instructor': 'Ventrella S',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Business Ethics'},
#  {'CRN': '75313',
#   'CatalogID': 'AE0291',
#   'Credits': '3',
#   'Instructor': 'Yoder J',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['W 0630-0900pm'],
#   'Title': 'Business Ethics'},
#  {'CRN': '76827',
#   'CatalogID': 'AE0291',
#   'Credits': '3',
#   'Instructor': 'Schmidt N',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Business Ethics'},
#  {'CRN': '76828',
#   'CatalogID': 'AE0291',
#   'Credits': '3',
#   'Instructor': 'Schmidt D',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Business Ethics'},
#  {'CRN': '75344',
#   'CatalogID': 'AR0110',
#   'Credits': '3',
#   'Instructor': 'Douda A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MW 0300-0445pm'],
#   'Title': 'Elementary Arabic I'},
#  {'CRN': '75402',
#   'CatalogID': 'AR0210',
#   'Credits': '3',
#   'Instructor': 'Douda A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MW 0500-0645pm'],
#   'Title': 'Intermediate Arabic I'},
#  {'CRN': '75745',
#   'CatalogID': 'AR0381',
#   'Credits': '3',
#   'Instructor': 'Douda A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0100-0200pm'],
#   'Title': 'Coordinating Seminar'},
#  {'CRN': '76861',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Poe A',
#   'Section': '01',
#   'Tags': [],
#   'Timecodes': ['Online'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '75165',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Schwab K',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0120pm', 'W 1200-1250pm'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '76861',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Poe A',
#   'Section': '01',
#   'Tags': [],
#   'Timecodes': ['Online'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '75165',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Schwab K',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0120pm', 'W 1200-1250pm'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '75166',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Eliasoph P',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '75559',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Rose M',
#   'Section': 'C01',
#   'Tags': ['CRNST'],
#   'Timecodes': ['TWF 1100-1150am'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '75167',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Eliasoph P',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '75168',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Eliasoph P',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '75432',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Rose M',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0120pm', 'W 0100-0150pm'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '76860',
#   'CatalogID': 'AH0010',
#   'Credits': '3',
#   'Instructor': 'Schwab K',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Origins & Transform Westrn Art'},
#  {'CRN': '76317',
#   'CatalogID': 'AH0013',
#   'Credits': '3',
#   'Instructor': 'Covaci I',
#   'Section': 'A',
#   'Tags': ['WDiv'],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Art/ Africa,Caribbean,Americas'},
#  {'CRN': '76318',
#   'CatalogID': 'AH0014',
#   'Credits': '3',
#   'Instructor': 'Covaci I',
#   'Section': 'A',
#   'Tags': ['WDiv'],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Art of Asia'},
#  {'CRN': '76862',
#   'CatalogID': 'AH0112',
#   'Credits': '3',
#   'Instructor': 'Rose M',
#   'Section': 'A',
#   'Tags': ['JUHAN'],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Etruscan & Roman Art & Archaeo'},
#  {'CRN': '76863',
#   'CatalogID': 'AH0130',
#   'Credits': '3',
#   'Instructor': 'Eliasoph P',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0200-0430pm'],
#   'Title': 'Renaissance Art in Italy'},
#  {'CRN': '76864',
#   'CatalogID': 'AH0172',
#   'Credits': '3',
#   'Instructor': 'Cesiro L',
#   'Section': 'A',
#   'Tags': ['ResColl'],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'History of Photography'},
#  {'CRN': '76865',
#   'CatalogID': 'AH0290B',
#   'Credits': '3',
#   'Instructor': 'Schwab K',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Topics: Hair in Classical Wrld'},
#  {'CRN': '75456',
#   'CatalogID': 'AN0310',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Asian Studies Seminar'},
#  {'CRN': '75944',
#   'CatalogID': 'BI0015',
#   'Credits': '3',
#   'Instructor': 'Blough C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'General Biology I'},
#  {'CRN': '76788',
#   'CatalogID': 'BI0015',
#   'Credits': '3',
#   'Instructor': 'Blough C',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'General Biology I'},
#  {'CRN': '75219',
#   'CatalogID': 'BI0018',
#   'Credits': '3',
#   'Instructor': 'Dutta I',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Human Biology: Form & Function'},
#  {'CRN': '75304',
#   'CatalogID': 'BI0018',
#   'Credits': '3',
#   'Instructor': 'Dutta I',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Human Biology: Form & Function'},
#  {'CRN': '76460',
#   'CatalogID': 'BI0070',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0800-0915am'],
#   'Title': 'Science, Technology & Society'},
#  {'CRN': '76461',
#   'CatalogID': 'BI0070',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Science, Technology & Society'},
#  {'CRN': '76287',
#   'CatalogID': 'BI0073',
#   'Credits': '3',
#   'Instructor': 'Vernarelli J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Contemp Nutr:Food for Thought'},
#  {'CRN': '76789',
#   'CatalogID': 'BI0074',
#   'Credits': '3',
#   'Instructor': 'Klug J',
#   'Section': 'A',
#   'Tags': ['Water'],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Biology of Food'},
#  {'CRN': '76790',
#   'CatalogID': 'BI0075',
#   'Credits': '3',
#   'Instructor': 'Choly J',
#   'Section': 'A',
#   'Tags': ['ResColl', 'Water'],
#   'Timecodes': ['MW 0630-0745pm'],
#   'Title': 'Ecology and Society'},
#  {'CRN': '76235',
#   'CatalogID': 'BI0078',
#   'Credits': '3',
#   'Instructor': 'Ortman B',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TR 0500-0615pm'],
#   'Title': 'Introduction to Marine Science'},
#  {'CRN': '76236',
#   'CatalogID': 'BI0078',
#   'Credits': '3',
#   'Instructor': 'Ortman B',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TR 0630-0745pm'],
#   'Title': 'Introduction to Marine Science'},
#  {'CRN': '76791',
#   'CatalogID': 'BI0096',
#   'Credits': '3',
#   'Instructor': 'Sauer G',
#   'Section': 'A',
#   'Tags': ['ResColl'],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'God and Modern Biology'},
#  {'CRN': '76422',
#   'CatalogID': 'BI0107',
#   'Credits': '4',
#   'Instructor': 'Earls C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Human Anatomy & Physiology'},
#  {'CRN': '75868',
#   'CatalogID': 'BI0107',
#   'Credits': '4',
#   'Instructor': 'Earls C',
#   'Section': 'A-C',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Human Anatomy & Physiology'},
#  {'CRN': '76423',
#   'CatalogID': 'BI0107',
#   'Credits': '4',
#   'Instructor': 'DeCristofaro A',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Human Anatomy & Physiology'},
#  {'CRN': '76120',
#   'CatalogID': 'BI0107',
#   'Credits': '4',
#   'Instructor': 'DeCristofaro A',
#   'Section': 'B-C',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Human Anatomy & Physiology'},
#  {'CRN': '75617',
#   'CatalogID': 'BI0107L',
#   'Credits': '0',
#   'Instructor': 'Earls C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0100-0350pm'],
#   'Title': 'Human Anatomy & Physiology Lab'},
#  {'CRN': '75621',
#   'CatalogID': 'BI0107L',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['T 0900-1150am'],
#   'Title': 'Human Anatomy & Physiology Lab'},
#  {'CRN': '75646',
#   'CatalogID': 'BI0107L',
#   'Credits': '0',
#   'Instructor': 'DeCristofaro A',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['W 0830-1120am'],
#   'Title': 'Human Anatomy & Physiology Lab'},
#  {'CRN': '75647',
#   'CatalogID': 'BI0107L',
#   'Credits': '0',
#   'Instructor': 'DeCristofaro A',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['W 1230-0320pm'],
#   'Title': 'Human Anatomy & Physiology Lab'},
#  {'CRN': '75653',
#   'CatalogID': 'BI0107L',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['W 0530-0820pm'],
#   'Title': 'Human Anatomy & Physiology Lab'},
#  {'CRN': '76060',
#   'CatalogID': 'BI0107L',
#   'Credits': '0',
#   'Instructor': 'Earls C',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['R 0100-0350pm'],
#   'Title': 'Human Anatomy & Physiology Lab'},
#  {'CRN': '76462',
#   'CatalogID': 'BI0107L',
#   'Credits': '0',
#   'Instructor': 'Earls C',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['F 1000-1250pm'],
#   'Title': 'Human Anatomy & Physiology Lab'},
#  {'CRN': '75279',
#   'CatalogID': 'BI0151',
#   'Credits': '4',
#   'Instructor': 'Zavras E',
#   'Section': 'A',
#   'Tags': ['NS Only'],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Elements of Microbiology'},
#  {'CRN': '75662',
#   'CatalogID': 'BI0151L',
#   'Credits': '0',
#   'Instructor': 'Zavras E',
#   'Section': 'A',
#   'Tags': ['NS Only'],
#   'Timecodes': ['M 0200-0450pm'],
#   'Title': 'Elements of Microbiology Lab'},
#  {'CRN': '75663',
#   'CatalogID': 'BI0151L',
#   'Credits': '0',
#   'Instructor': 'Zavras E',
#   'Section': 'B',
#   'Tags': ['NS Only'],
#   'Timecodes': ['T 0200-0450pm'],
#   'Title': 'Elements of Microbiology Lab'},
#  {'CRN': '75664',
#   'CatalogID': 'BI0151L',
#   'Credits': '0',
#   'Instructor': 'Zavras E',
#   'Section': 'C',
#   'Tags': ['NS Only'],
#   'Timecodes': ['R 0200-0450pm'],
#   'Title': 'Elements of Microbiology Lab'},
#  {'CRN': '76424',
#   'CatalogID': 'BI0170',
#   'Credits': '4',
#   'Instructor': 'Fernandez A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'General Biology I'},
#  {'CRN': '75468',
#   'CatalogID': 'BI0170',
#   'Credits': '4',
#   'Instructor': 'Fernandez A',
#   'Section': 'A-C',
#   'Tags': ['CRNST'],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'General Biology I'},
#  {'CRN': '76425',
#   'CatalogID': 'BI0170',
#   'Credits': '4',
#   'Instructor': 'Fernandez A',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'General Biology I'},
#  {'CRN': '75212',
#   'CatalogID': 'BI0170',
#   'Credits': '4',
#   'Instructor': 'Fernandez A',
#   'Section': 'B-C',
#   'Tags': ['CRNST'],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'General Biology I'},
#  {'CRN': '75665',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'Braun P',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75666',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'Biardi L',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['M 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75667',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'Andersen C',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['T 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75668',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'Phelan S',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['T 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75669',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'Andersen C',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['W 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75670',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['W 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75671',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['W 0530-0820pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75672',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'Braun P',
#   'Section': 'H',
#   'Tags': [],
#   'Timecodes': ['R 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75673',
#   'CatalogID': 'BI0170L',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'I',
#   'Tags': [],
#   'Timecodes': ['R 0200-0450pm'],
#   'Title': 'General Biology I Lab'},
#  {'CRN': '75674',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0300-0350pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75675',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['T 0400-0450pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75677',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['T 0500-0550pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75679',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['T 0600-0650pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75680',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['W 0300-0330pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75681',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['W 0400-0450pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75682',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['W 0500-0550pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75683',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'H',
#   'Tags': [],
#   'Timecodes': ['W 0600-0650pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75684',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'I',
#   'Tags': [],
#   'Timecodes': ['R 0300-0350pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75685',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'J',
#   'Tags': [],
#   'Timecodes': ['R 0400-0450pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75686',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'K',
#   'Tags': [],
#   'Timecodes': ['R 0500-0550pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75687',
#   'CatalogID': 'BI0170P',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'L',
#   'Tags': [],
#   'Timecodes': ['R 0600-0650pm'],
#   'Title': 'General Biology I PLG'},
#  {'CRN': '75250',
#   'CatalogID': 'BI0172',
#   'Credits': '4',
#   'Instructor': 'Biardi J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'General Biology III'},
#  {'CRN': '75688',
#   'CatalogID': 'BI0172L',
#   'Credits': '0',
#   'Instructor': 'Biardi J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0200-0450pm'],
#   'Title': 'General Biology III Lab'},
#  {'CRN': '75689',
#   'CatalogID': 'BI0172L',
#   'Credits': '0',
#   'Instructor': 'Osier T',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['T 0200-0450pm'],
#   'Title': 'General Biology III Lab'},
#  {'CRN': '75690',
#   'CatalogID': 'BI0172L',
#   'Credits': '0',
#   'Instructor': 'Osier T',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['W 0200-0450pm'],
#   'Title': 'General Biology III Lab'},
#  {'CRN': '75691',
#   'CatalogID': 'BI0172L',
#   'Credits': '0',
#   'Instructor': 'Ansari J',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['W 0200-0450pm'],
#   'Title': 'General Biology III Lab'},
#  {'CRN': '76430',
#   'CatalogID': 'BI0172L',
#   'Credits': '0',
#   'Instructor': 'Brousseau D',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['R 0200-0450pm'],
#   'Title': 'General Biology III Lab'},
#  {'CRN': '75695',
#   'CatalogID': 'BI0201',
#   'Credits': '1',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['By Arrangement'],
#   'Title': 'Biology Teaching Practicum'},
#  {'CRN': '75758',
#   'CatalogID': 'BI0202',
#   'Credits': '1',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['By Arrangement'],
#   'Title': 'Biology Teaching Practicum'},
#  {'CRN': '75759',
#   'CatalogID': 'BI0203',
#   'Credits': '1',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['By Arrangement'],
#   'Title': 'Biology Teaching Practicum'},
#  {'CRN': '76237',
#   'CatalogID': 'BI0204',
#   'Credits': '1',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['By Arrangement'],
#   'Title': 'Biology Teaching Practicum'},
#  {'CRN': '76238',
#   'CatalogID': 'BI0205',
#   'Credits': '1',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['By Arrangement'],
#   'Title': 'Biology Teaching Practicum'},
#  {'CRN': '76792',
#   'CatalogID': 'BI0206',
#   'Credits': '1',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['By Arrangement'],
#   'Title': 'Biology Teaching Practicum'},
#  {'CRN': '76793',
#   'CatalogID': 'BI0262',
#   'Credits': '4',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Human Physiology'},
#  {'CRN': '76794',
#   'CatalogID': 'BI0262L',
#   'Credits': '0',
#   'Instructor': 'Gerry S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0200-0450pm'],
#   'Title': 'Human Physiology Lab'},
#  {'CRN': '75066',
#   'CatalogID': 'BI0296',
#   'Credits': '3',
#   'Instructor': 'Harriott O',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['By Arrangement'],
#   'Title': 'Special Topics in Biology'},
#  {'CRN': '76798',
#   'CatalogID': 'BI0317',
#   'Credits': '4',
#   'Instructor': 'Vernarelli J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Epidemiology & Applied Biostat'},
#  {'CRN': '76239',
#   'CatalogID': 'BI0324',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Biochemistry I'},
#  {'CRN': '76795',
#   'CatalogID': 'BI0324L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0200-0450pm'],
#   'Title': 'Biochemistry I Lab'},
#  {'CRN': '76796',
#   'CatalogID': 'BI0325',
#   'Credits': '3',
#   'Instructor': 'Sauer G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Biochemistry II'},
#  {'CRN': '76797',
#   'CatalogID': 'BI0325L',
#   'Credits': '1',
#   'Instructor': 'Sauer G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0200-0450pm'],
#   'Title': 'Biochemistry II Lab'},
#  {'CRN': '75415',
#   'CatalogID': 'BI0352',
#   'Credits': '4',
#   'Instructor': 'Harriott O',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Fundamentals of Microbiology'},
#  {'CRN': '75694',
#   'CatalogID': 'BI0352L',
#   'Credits': '0',
#   'Instructor': 'Harriott O',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0930-1220pm'],
#   'Title': 'Fund. of Microbiology Lab'},
#  {'CRN': '75575',
#   'CatalogID': 'BI0354',
#   'Credits': '3',
#   'Instructor': 'Braun P',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Molecular Biology'},
#  {'CRN': '75280',
#   'CatalogID': 'BI0362',
#   'Credits': '4',
#   'Instructor': 'Brousseau D',
#   'Section': 'A',
#   'Tags': ['Water'],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Marine Invertebrate Zoology'},
#  {'CRN': '75692',
#   'CatalogID': 'BI0362L',
#   'Credits': '0',
#   'Instructor': 'Brousseau D',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0200-0450pm'],
#   'Title': 'Marine Invertebrate Zoolgy Lab'},
#  {'CRN': '75450',
#   'CatalogID': 'BI0365',
#   'Credits': '4',
#   'Instructor': 'Byun S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Evolutionary Biology'},
#  {'CRN': '75693',
#   'CatalogID': 'BI0365L',
#   'Credits': '0',
#   'Instructor': 'Byun S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0100-0350pm'],
#   'Title': 'Evolutionary Biology Lab'},
#  {'CRN': '76800',
#   'CatalogID': 'BI0381B',
#   'Credits': '3',
#   'Instructor': 'Phelan S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Sem: Molec Mech /Human Disease'},
#  {'CRN': '76801',
#   'CatalogID': 'BI0381D',
#   'Credits': '3',
#   'Instructor': 'Andersen C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Sem: Nutritional Epigenetics'},
#  {'CRN': '75416',
#   'CatalogID': 'BI0391',
#   'Credits': '3',
#   'Instructor': 'Biardi J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Biology Research I'},
#  {'CRN': '75417',
#   'CatalogID': 'BI0392',
#   'Credits': '2',
#   'Instructor': 'Biardi J',
#   'Section': 'A2',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Biology Research II'},
#  {'CRN': '76434',
#   'CatalogID': 'BI0392',
#   'Credits': '3',
#   'Instructor': 'Biardi J',
#   'Section': 'A3',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Biology Research II'},
#  {'CRN': '75418',
#   'CatalogID': 'BI0393',
#   'Credits': '3',
#   'Instructor': 'Biardi J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Biology Research III'},
#  {'CRN': '76802',
#   'CatalogID': 'BI0394',
#   'Credits': '3',
#   'Instructor': 'Biardi J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Biology Research IV'},
#  {'CRN': '76783',
#   'CatalogID': 'CH0007',
#   'Credits': '3',
#   'Instructor': 'Harper-Leatherman A',
#   'Section': 'A',
#   'Tags': ['ResColl'],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Intro to Forensic Science'},
#  {'CRN': '76100',
#   'CatalogID': 'CH0010',
#   'Credits': '3',
#   'Instructor': 'O̥Connell E',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Chemistry: Sights & Insights'},
#  {'CRN': '75152',
#   'CatalogID': 'CH0083',
#   'Credits': '3',
#   'Instructor': 'Bethray S',
#   'Section': 'A',
#   'Tags': ['Water'],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Survey of Chemistry'},
#  {'CRN': '75293',
#   'CatalogID': 'CH0084',
#   'Credits': '3',
#   'Instructor': 'Reilly-Wiedow E',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Gen Chem for Health Science'},
#  {'CRN': '75589',
#   'CatalogID': 'CH0084L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0900-1150am'],
#   'Title': 'Gen Chem Health Science Lab'},
#  {'CRN': '75590',
#   'CatalogID': 'CH0084L',
#   'Credits': '1',
#   'Instructor': 'Reilly-Wiedow E',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['T 0900-1150am'],
#   'Title': 'Gen Chem Health Science Lab'},
#  {'CRN': '75591',
#   'CatalogID': 'CH0084L',
#   'Credits': '1',
#   'Instructor': 'Reilly-Wiedow E',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['W 0900-1150am'],
#   'Title': 'Gen Chem Health Science Lab'},
#  {'CRN': '76245',
#   'CatalogID': 'CH0084L',
#   'Credits': '1',
#   'Instructor': 'Reilly-Wiedow E',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['R 0900-1150am'],
#   'Title': 'Gen Chem Health Science Lab'},
#  {'CRN': '75588',
#   'CatalogID': 'CH0085',
#   'Credits': '3',
#   'Instructor': 'Steffen L',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Chemistry,Energy & Environment'},
#  {'CRN': '75457',
#   'CatalogID': 'CH0086',
#   'Credits': '3',
#   'Instructor': 'Sobczynski D',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TR 0500-0615pm'],
#   'Title': 'Chemistry and Art'},
#  {'CRN': '75600',
#   'CatalogID': 'CH0111',
#   'Credits': '3',
#   'Instructor': 'STAFF EG Only',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0600-0900pm'],
#   'Title': 'General Chemistry I'},
#  {'CRN': '75601',
#   'CatalogID': 'CH0111',
#   'Credits': '3',
#   'Instructor': 'Fischer R',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm', 'W 1200-1250pm'],
#   'Title': 'General Chemistry I'},
#  {'CRN': '75602',
#   'CatalogID': 'CH0111',
#   'Credits': '3',
#   'Instructor': 'Kubasik M',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['R 0200-0250pm', 'TF 0830-0920am', 'W 0800-0850am'],
#   'Title': 'General Chemistry I'},
#  {'CRN': '75603',
#   'CatalogID': 'CH0111',
#   'Credits': '3',
#   'Instructor': 'Weddle G',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['M 1100-1150am', 'TWF 1100-1150am'],
#   'Title': 'General Chemistry I'},
#  {'CRN': '75604',
#   'CatalogID': 'CH0111',
#   'Credits': '3',
#   'Instructor': 'Weddle G',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['M 0930-1020am', 'TWF 0930-1020am'],
#   'Title': 'General Chemistry I'},
#  {'CRN': '75718',
#   'CatalogID': 'CH0111',
#   'Credits': '3',
#   'Instructor': 'Fischer R',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm', 'W 1000-1050am'],
#   'Title': 'General Chemistry I'},
#  {'CRN': '75578',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 1230-0320pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75579',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['M 0500-0750pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75580',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'Weddle G',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['T 1230-0320pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75581',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'Fischer S',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['T 0500-0750pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75582',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'Fischer S',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['W 0100-0350pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75583',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['W 0500-0750pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75584',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'Harper J',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['R 1230-0320pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75585',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'H',
#   'Tags': [],
#   'Timecodes': ['R 0500-0750pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75586',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'I',
#   'Tags': [],
#   'Timecodes': ['F 0900-1150am'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75587',
#   'CatalogID': 'CH0111L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'J',
#   'Tags': [],
#   'Timecodes': ['F 1230-0320pm'],
#   'Title': 'General Chemistry I Lab'},
#  {'CRN': '75061',
#   'CatalogID': 'CH0211',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am', 'W 0800-0850am'],
#   'Title': 'Organic Chemistry I'},
#  {'CRN': '75062',
#   'CatalogID': 'CH0211',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am', 'W 1000-1050am'],
#   'Title': 'Organic Chemistry I'},
#  {'CRN': '75473',
#   'CatalogID': 'CH0211',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am', 'W 0900-0950am'],
#   'Title': 'Organic Chemistry I'},
#  {'CRN': '75592',
#   'CatalogID': 'CH0211L',
#   'Credits': '1',
#   'Instructor': 'Lloyd J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 1230-0430pm'],
#   'Title': 'Organic Chemistry I Lab'},
#  {'CRN': '75593',
#   'CatalogID': 'CH0211L',
#   'Credits': '1',
#   'Instructor': 'Schirmann P',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['T 1230-0430pm'],
#   'Title': 'Organic Chemistry I Lab'},
#  {'CRN': '75594',
#   'CatalogID': 'CH0211L',
#   'Credits': '1',
#   'Instructor': 'Lloyd J',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['W 0100-0500pm'],
#   'Title': 'Organic Chemistry I Lab'},
#  {'CRN': '75595',
#   'CatalogID': 'CH0211L',
#   'Credits': '1',
#   'Instructor': 'O̥Connell E',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['R 1230-0430pm'],
#   'Title': 'Organic Chemistry I Lab'},
#  {'CRN': '75596',
#   'CatalogID': 'CH0211L',
#   'Credits': '1',
#   'Instructor': 'Schirmann P',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['R 0500-0850pm'],
#   'Title': 'Organic Chemistry I Lab'},
#  {'CRN': '75597',
#   'CatalogID': 'CH0211L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['F 1230-0430pm'],
#   'Title': 'Organic Chemistry I Lab'},
#  {'CRN': '75063',
#   'CatalogID': 'CH0261',
#   'Credits': '3',
#   'Instructor': 'Kubasik M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TWF 1100-1150am'],
#   'Title': 'Physical Chemistry I'},
#  {'CRN': '75598',
#   'CatalogID': 'CH0261L',
#   'Credits': '1',
#   'Instructor': 'Kubasik M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0200-0450pm'],
#   'Title': 'Physical Chemistry I Lab'},
#  {'CRN': '76246',
#   'CatalogID': 'CH0324',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Biochemistry I'},
#  {'CRN': '76784',
#   'CatalogID': 'CH0324L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0200-0450pm'],
#   'Title': 'Biochemistry I Lab'},
#  {'CRN': '76785',
#   'CatalogID': 'CH0325',
#   'Credits': '3',
#   'Instructor': 'Sauer G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Biochemistry II'},
#  {'CRN': '76786',
#   'CatalogID': 'CH0325L',
#   'Credits': '1',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0200-0450pm'],
#   'Title': 'Biochemistry II Lab'},
#  {'CRN': '75294',
#   'CatalogID': 'CH0326',
#   'Credits': '3',
#   'Instructor': 'Harper-Leatherman A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Chemical Instrumentation'},
#  {'CRN': '75348',
#   'CatalogID': 'CI0110',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TWF 0200-0250pm'],
#   'Title': 'Elementary Chinese I'},
#  {'CRN': '75349',
#   'CatalogID': 'CI0210',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0130pm', 'W 0100-0150pm'],
#   'Title': 'Intermediate Chinese I'},
#  {'CRN': '76773',
#   'CatalogID': 'CL0106',
#   'Credits': '3',
#   'Instructor': 'Rosivach V',
#   'Section': 'A',
#   'Tags': ['English Core'],
#   'Timecodes': ['W 0630-0900pm'],
#   'Title': 'MasterpiecesGrk Lit/Eng Transl'},
#  {'CRN': '76242',
#   'CatalogID': 'CL0116',
#   'Credits': '3',
#   'Instructor': 'Ruffini G',
#   'Section': 'A',
#   'Tags': ['History Core'],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Roman Civilization'},
#  {'CRN': '76243',
#   'CatalogID': 'CL0116',
#   'Credits': '3',
#   'Instructor': 'Ruffini G',
#   'Section': 'B',
#   'Tags': ['History Core'],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Roman Civilization'},
#  {'CRN': '75134',
#   'CatalogID': 'CO0100',
#   'Credits': '3',
#   'Instructor': 'Ryan M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TWF 1100-1150am'],
#   'Title': 'Human Communication Theories'},
#  {'CRN': '75148',
#   'CatalogID': 'CO0100',
#   'Credits': '3',
#   'Instructor': 'Brennan N',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Human Communication Theories'},
#  {'CRN': '75133',
#   'CatalogID': 'CO0100',
#   'Credits': '3',
#   'Instructor': 'Ryan M',
#   'Section': 'C01',
#   'Tags': ['CRNST'],
#   'Timecodes': ['TF 0930-1020am', 'W 0900-0950am'],
#   'Title': 'Human Communication Theories'},
#  {'CRN': '75721',
#   'CatalogID': 'CO0100',
#   'Credits': '3',
#   'Instructor': 'Brennan N',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['TF 0330-0445pm'],
#   'Title': 'Human Communication Theories'},
#  {'CRN': '75135',
#   'CatalogID': 'CO0101',
#   'Credits': '3',
#   'Instructor': 'D̥Amico C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Argument and Advocacy'},
#  {'CRN': '75136',
#   'CatalogID': 'CO0101',
#   'Credits': '3',
#   'Instructor': 'D̥Amico C',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Argument and Advocacy'},
#  {'CRN': '75190',
#   'CatalogID': 'CO0101',
#   'Credits': '3',
#   'Instructor': 'Larkin T',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Argument and Advocacy'},
#  {'CRN': '75543',
#   'CatalogID': 'CO0101',
#   'Credits': '3',
#   'Instructor': 'Smith J',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Argument and Advocacy'},
#  {'CRN': '75544',
#   'CatalogID': 'CO0101',
#   'Credits': '3',
#   'Instructor': 'Smith J',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Argument and Advocacy'},
#  {'CRN': '76782',
#   'CatalogID': 'CO0102',
#   'Credits': '3',
#   'Instructor': 'Arendt C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MW 0500-0615pm'],
#   'Title': 'Intro to Public Relations'},
#  {'CRN': '75334',
#   'CatalogID': 'CO0130',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Mass Media and Society'},
#  {'CRN': '75335',
#   'CatalogID': 'CO0130',
#   'Credits': '3',
#   'Instructor': 'Duarte L',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['R 0700-0930pm'],
#   'Title': 'Mass Media and Society'},
#  {'CRN': '76495',
#   'CatalogID': 'CO0130',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['TF 0800-0915am'],
#   'Title': 'Mass Media and Society'},
#  {'CRN': '75234',
#   'CatalogID': 'CO0200',
#   'Credits': '3',
#   'Instructor': 'Nuru A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Interpersonal Comm Theories'},
#  {'CRN': '75472',
#   'CatalogID': 'CO0200',
#   'Credits': '3',
#   'Instructor': 'Ryan M',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Interpersonal Comm Theories'},
#  {'CRN': '75195',
#   'CatalogID': 'CO0220',
#   'Credits': '3',
#   'Instructor': 'Pagano M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Intro Organizational Comm'},
#  {'CRN': '76249',
#   'CatalogID': 'CO0231',
#   'Credits': '3',
#   'Instructor': 'Gil-Egui G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Media Institutions'},
#  {'CRN': '76759',
#   'CatalogID': 'CO0231',
#   'Credits': '3',
#   'Instructor': 'Gil-Egui G',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Media Institutions'},
#  {'CRN': '76760',
#   'CatalogID': 'CO0236',
#   'Credits': '3',
#   'Instructor': 'Gudelunas D',
#   'Section': 'A',
#   'Tags': ['USDiv'],
#   'Timecodes': ['M 0500-0730pm'],
#   'Title': 'Gender, Sexuality, and Media'},
#  {'CRN': '76250',
#   'CatalogID': 'CO0238',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Comm & Popular Culture'},
#  {'CRN': '75545',
#   'CatalogID': 'CO0248',
#   'Credits': '3',
#   'Instructor': 'Pagano M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Health Communication'},
#  {'CRN': '75137',
#   'CatalogID': 'CO0309',
#   'Credits': '3',
#   'Instructor': 'Wills M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Research Proj in Comm:Capstone'},
#  {'CRN': '75138',
#   'CatalogID': 'CO0309',
#   'Credits': '3',
#   'Instructor': 'Wills M',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Research Proj in Comm:Capstone'},
#  {'CRN': '75174',
#   'CatalogID': 'CO0309',
#   'Credits': '3',
#   'Instructor': 'Nuru A',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Research Proj in Comm:Capstone'},
#  {'CRN': '75720',
#   'CatalogID': 'CO0309',
#   'Credits': '3',
#   'Instructor': 'Nuru A',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Research Proj in Comm:Capstone'},
#  {'CRN': '76761',
#   'CatalogID': 'CO0321',
#   'Credits': '3',
#   'Instructor': 'Pagano M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0500-0615pm'],
#   'Title': 'Comm Proc in Orgs: Negotiation'},
#  {'CRN': '76762',
#   'CatalogID': 'CO0331',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'American Media / Amer History'},
#  {'CRN': '76763',
#   'CatalogID': 'CO0342',
#   'Credits': '3',
#   'Instructor': 'Gil-Egui G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0500-0730pm'],
#   'Title': 'Technoculture & Info Society'},
#  {'CRN': '76254',
#   'CatalogID': 'CO0345',
#   'Credits': '3',
#   'Instructor': 'Zhang Q',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Relational Communication'},
#  {'CRN': '76764',
#   'CatalogID': 'CO0346',
#   'Credits': '3',
#   'Instructor': 'Wills M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Communication and Spirituality'},
#  {'CRN': '75142',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Aksan A',
#   'Section': 'C01',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75143',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Lane P',
#   'Section': 'C02',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75388',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Aksan A',
#   'Section': 'C03',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75877',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Murray T',
#   'Section': 'C04',
#   'Tags': ['CRNST'],
#   'Timecodes': ['TF 0800-0915am'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75878',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Murray T',
#   'Section': 'C05',
#   'Tags': ['CRNST'],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76116',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Murray T',
#   'Section': 'C06',
#   'Tags': ['CRNST'],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75141',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Franceschi D',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75144',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Franceschi D',
#   'Section': 'H',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75145',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'McCloghry G',
#   'Section': 'I',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75146',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Martin T',
#   'Section': 'J',
#   'Tags': [],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75147',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Martin T',
#   'Section': 'K',
#   'Tags': [],
#   'Timecodes': ['TF 0330-0445pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75386',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Martin T',
#   'Section': 'L',
#   'Tags': [],
#   'Timecodes': ['MR 0500-0615pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75387',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'McCloghry G',
#   'Section': 'M',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75389',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Shadmani H',
#   'Section': 'N',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75732',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Martin T',
#   'Section': 'O',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '75869',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Shadmani H',
#   'Section': 'P',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76492',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'Shadmani H',
#   'Section': 'Q',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76506',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'R',
#   'Tags': [],
#   'Timecodes': ['TBA'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76507',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'S',
#   'Tags': [],
#   'Timecodes': ['TBA'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76508',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'T',
#   'Tags': [],
#   'Timecodes': ['TBA'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76509',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'U',
#   'Tags': [],
#   'Timecodes': ['TBA'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76928',
#   'CatalogID': 'EC0011',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'V',
#   'Tags': [],
#   'Timecodes': ['TBA'],
#   'Title': 'Introduction to Microeconomics'},
#  {'CRN': '76929',
#   'CatalogID': 'EC0114',
#   'Credits': '3',
#   'Instructor': 'Nantz K',
#   'Section': 'A',
#   'Tags': ['USDiv'],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Race,Class,Gendr in Amer Wkplc'},
#  {'CRN': '75006',
#   'CatalogID': 'EC0204',
#   'Credits': '3',
#   'Instructor': 'Nantz K',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1230-0145pm'],
#   'Title': 'Interm Microeconomic Theory'},
#  {'CRN': '75193',
#   'CatalogID': 'EC0204',
#   'Credits': '3',
#   'Instructor': 'Nantz K',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Interm Microeconomic Theory'},
#  {'CRN': '75493',
#   'CatalogID': 'EC0204L',
#   'Credits': '1',
#   'Instructor': 'Nantz K',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0100-0150pm'],
#   'Title': 'Interm Micro Econ Theory Lab'},
#  {'CRN': '75007',
#   'CatalogID': 'EC0210',
#   'Credits': '3',
#   'Instructor': 'Lane P',
#   'Section': 'A',
#   'Tags': ['ResColl'],
#   'Timecodes': ['MR 0930-1020am', 'W 0900-0950am'],
#   'Title': 'Money and Banking'},
#  {'CRN': '76363',
#   'CatalogID': 'EC0230',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': ['WDiv'],
#   'Timecodes': ['TF 0330-0445pm'],
#   'Title': 'Comparative Economic Systems'},
#  {'CRN': '76930',
#   'CatalogID': 'EC0235',
#   'Credits': '3',
#   'Instructor': 'Aksan A',
#   'Section': 'A',
#   'Tags': ['WDiv'],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Economic Development'},
#  {'CRN': '75008',
#   'CatalogID': 'EC0278',
#   'Credits': '3',
#   'Instructor': 'Vasquez Mazariegos',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Statistics'},
#  {'CRN': '76931',
#   'CatalogID': 'EC0278',
#   'Credits': '3',
#   'Instructor': 'Vasquez Mazariegos',
#   'Section': 'B',
#   'Tags': [],
# ...
#   'Section': 'B',
#   'Tags': ['Water'],
#   'Timecodes': ['TF 0330-0445pm'],
#   'Title': 'Public Relations'},
#  {'CRN': '75265',
#   'CatalogID': 'OM0101',
#   'Credits': '3',
#   'Instructor': 'He J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Operations Management'},
#  {'CRN': '75266',
#   'CatalogID': 'OM0101',
#   'Credits': '3',
#   'Instructor': 'He J',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Operations Management'},
#  {'CRN': '75267',
#   'CatalogID': 'OM0101',
#   'Credits': '3',
#   'Instructor': 'Lee P',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Operations Management'},
#  {'CRN': '75268',
#   'CatalogID': 'OM0101',
#   'Credits': '3',
#   'Instructor': 'Lee P',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Operations Management'},
#  {'CRN': '75269',
#   'CatalogID': 'OM0101',
#   'Credits': '3',
#   'Instructor': 'Lee P',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'Operations Management'},
#  {'CRN': '76387',
#   'CatalogID': 'OM0101',
#   'Credits': '3',
#   'Instructor': 'Krishnamoorthy J',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Operations Management'},
#  {'CRN': '76699',
#   'CatalogID': 'OM0101',
#   'Credits': '3',
#   'Instructor': 'Sklar D',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['R 0600-0900pm'],
#   'Title': 'Operations Management'},
#  {'CRN': '75278',
#   'CatalogID': 'EG0031',
#   'Credits': '3',
#   'Instructor': 'Munden R',
#   'Section': 'C01',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Fundamentals of Engineering I'},
#  {'CRN': '75848',
#   'CatalogID': 'EG0031',
#   'Credits': '3',
#   'Instructor': 'Munden R',
#   'Section': 'C02',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Fundamentals of Engineering I'},
#  {'CRN': '76726',
#   'CatalogID': 'EG0031',
#   'Credits': '3',
#   'Instructor': 'Munden R',
#   'Section': 'C03',
#   'Tags': ['CRNST'],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Fundamentals of Engineering I'},
#  {'CRN': '75488',
#   'CatalogID': 'EG0390',
#   'Credits': '3',
#   'Instructor': 'Munden R',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0500-0615pm'],
#   'Title': 'Senior Design Project I'},
#  {'CRN': '75574',
#   'CatalogID': 'CD0212',
#   'Credits': '3',
#   'Instructor': 'Waugh K',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0630-0900pm'],
#   'Title': 'Engineering Graphics II (CATIA)'},
#  {'CRN': '76400',
#   'CatalogID': 'CR0246',
#   'Credits': '3',
#   'Instructor': 'Cavallo J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Digital Electronics Design II'},
#  {'CRN': '76710',
#   'CatalogID': 'CR0325',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Computer Graphics'},
#  {'CRN': '76711',
#   'CatalogID': 'CR0331',
#   'Credits': '3',
#   'Instructor': 'Lyon D',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Biomedical Signal Processing'},
#  {'CRN': '76712',
#   'CatalogID': 'CR0346',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Computer System Architecture'},
#  {'CRN': '76728',
#   'CatalogID': 'EE0207',
#   'Credits': '3',
#   'Instructor': 'Govil P',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0630-0900pm'],
#   'Title': 'Electronic Materials'},
#  {'CRN': '75161',
#   'CatalogID': 'EE0213',
#   'Credits': '3',
#   'Instructor': 'Balaji U',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 1100-1215pm'],
#   'Title': 'Intro to Electric Circuits'},
#  {'CRN': '75226',
#   'CatalogID': 'EE0213',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Intro Electric Circuits(PS/EG)'},
#  {'CRN': '75710',
#   'CatalogID': 'EE0213L',
#   'Credits': '1',
#   'Instructor': 'Cavallo J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0630-0830pm'],
#   'Title': 'Electric Circuits Lab (PS/EG)'},
#  {'CRN': '75711',
#   'CatalogID': 'EE0213L',
#   'Credits': '1',
#   'Instructor': 'Denenberg J',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['W 1100-0130pm'],
#   'Title': 'Electric Circuits Lab'},
#  {'CRN': '76125',
#   'CatalogID': 'EE0213L',
#   'Credits': '1',
#   'Instructor': 'Denenberg J',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['T 0200-0430pm'],
#   'Title': 'Electric Circuits Lab'},
#  {'CRN': '75204',
#   'CatalogID': 'EE0231',
#   'Credits': '3',
#   'Instructor': 'Balaji U',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Intro to ElectCircuits&Devices'},
#  {'CRN': '75717',
#   'CatalogID': 'EE0231L',
#   'Credits': '1',
#   'Instructor': 'Denenberg J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0500-0730pm'],
#   'Title': 'Electronics Circuits Lab'},
#  {'CRN': '75205',
#   'CatalogID': 'EE0301',
#   'Credits': '3',
#   'Instructor': 'Balaji U',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Signal & Systems I'},
#  {'CRN': '76723',
#   'CatalogID': 'EE0315',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['F 0630-0900pm'],
#   'Title': 'Nanoelectronics'},
#  {'CRN': '75409',
#   'CatalogID': 'EE0346',
#   'Credits': '3',
#   'Instructor': 'Lopes E',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0630-0900pm'],
#   'Title': 'Embedded Microcontrollers'},
#  {'CRN': '76724',
#   'CatalogID': 'EE0383',
#   'Credits': '3',
#   'Instructor': 'Denenberg J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Wireless Systems I'},
#  {'CRN': '76725',
#   'CatalogID': 'EE0385',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['U 0930-1130am'],
#   'Title': 'Powr Generation & Distribution'},
#  {'CRN': '75208',
#   'CatalogID': 'MC0290',
#   'Credits': '3',
#   'Instructor': 'Srinivas Sundarram S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0930-1045am'],
#   'Title': 'Engineering Systems Dynamics'},
#  {'CRN': '76401',
#   'CatalogID': 'MC0290',
#   'Credits': '3',
#   'Instructor': 'Srinivas Sundarram S',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['TF 0930-1045am'],
#   'Title': 'Engineering Systems Dynamics'},
#  {'CRN': '75300',
#   'CatalogID': 'ME0201',
#   'Credits': '3',
#   'Instructor': 'Zabinski M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Engineering Statics'},
#  {'CRN': '75815',
#   'CatalogID': 'ME0201',
#   'Credits': '3',
#   'Instructor': 'Zabinski M',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'Engineering Statics'},
#  {'CRN': '76729',
#   'CatalogID': 'ME0201',
#   'Credits': '3',
#   'Instructor': 'Zabinski M',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['MR 0500-0615pm'],
#   'Title': 'Engineering Statics'},
#  {'CRN': '75713',
#   'CatalogID': 'ME0206L',
#   'Credits': '1',
#   'Instructor': 'Selsky G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 1230-0230pm'],
#   'Title': 'Mechanics Lab'},
#  {'CRN': '75714',
#   'CatalogID': 'ME0206L',
#   'Credits': '1',
#   'Instructor': 'Selsky G',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['T 0330-0530pm'],
#   'Title': 'Mechanics Lab'},
#  {'CRN': '75744',
#   'CatalogID': 'ME0206L',
#   'Credits': '1',
#   'Instructor': 'Selsky G',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['T 0630-0830pm'],
#   'Title': 'Mechanics Lab'},
#  {'CRN': '75247',
#   'CatalogID': 'ME0241',
#   'Credits': '3',
#   'Instructor': 'Etemad S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'Principles of Thermodynamics'},
#  {'CRN': '75064',
#   'CatalogID': 'ME0241',
#   'Credits': '3',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Principles of Thermodynamics'},
#  {'CRN': '75065',
#   'CatalogID': 'ME0311',
#   'Credits': '3',
#   'Instructor': 'Srinivas Sundarram S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Machine Design'},
#  {'CRN': '76402',
#   'CatalogID': 'ME0311',
#   'Credits': '3',
#   'Instructor': 'Dornfeld W',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['R 0630-0900pm'],
#   'Title': 'Machine Design'},
#  {'CRN': '76730',
#   'CatalogID': 'ME0319',
#   'Credits': '3',
#   'Instructor': 'Bauer G',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0630-0900pm'],
#   'Title': 'Appl of Finite Element Analys'},
#  {'CRN': '76399',
#   'CatalogID': 'ME0321',
#   'Credits': '3',
#   'Instructor': 'Gunawardana R',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Advanced Kinematics'},
#  {'CRN': '75465',
#   'CatalogID': 'ME0322',
#   'Credits': '3',
#   'Instructor': 'Judge A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0630-0900pm'],
#   'Title': 'Advanced Dynamics'},
#  {'CRN': '76731',
#   'CatalogID': 'ME0346',
#   'Credits': '3',
#   'Instructor': 'Anekwe C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0630-0900pm'],
#   'Title': 'Energy Conversion'},
#  {'CRN': '75573',
#   'CatalogID': 'ME0349',
#   'Credits': '3',
#   'Instructor': 'Etemad S',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['TF 0200-0315pm'],
#   'Title': 'Heat Transfer'},
#  {'CRN': '75176',
#   'CatalogID': 'ME0349',
#   'Credits': '3',
#   'Instructor': 'Etemad S',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Heat Transfer'},
#  {'CRN': '75715',
#   'CatalogID': 'ME0350L',
#   'Credits': '1',
#   'Instructor': 'Wojna R',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0330-0530pm'],
#   'Title': 'Energy Transfer Lab'},
#  {'CRN': '75716',
#   'CatalogID': 'ME0350L',
#   'Credits': '1',
#   'Instructor': 'Cupic K',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['M 0630-0830pm'],
#   'Title': 'Energy Transfer Lab'},
#  {'CRN': '75466',
#   'CatalogID': 'MF0207',
#   'Credits': '3',
#   'Instructor': 'Lutian M',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Materials Science'},
#  {'CRN': '75742',
#   'CatalogID': 'MF0207',
#   'Credits': '3',
#   'Instructor': 'Lutian M',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['R 0630-0900pm'],
#   'Title': 'Materials Science'},
#  {'CRN': '76404',
#   'CatalogID': 'MF0350',
#   'Credits': '3',
#   'Instructor': 'Craciun C',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Adv Prog LogicContrl (PLC)Syst'},
#  {'CRN': '75206',
#   'CatalogID': 'SW0201',
#   'Credits': '3',
#   'Instructor': 'Rusu A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0200-0430pm'],
#   'Title': 'Software Engineering Methods'},
#  {'CRN': '75306',
#   'CatalogID': 'SW0202',
#   'Credits': '3',
#   'Instructor': 'Rusu A',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'Software Design Methods'},
#  {'CRN': '75816',
#   'CatalogID': 'SW0204',
#   'Credits': '3',
#   'Instructor': 'Guelakis W',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0630-0900pm'],
#   'Title': 'Software Project Management'},
#  {'CRN': '75817',
#   'CatalogID': 'SW0232',
#   'Credits': '3',
#   'Instructor': 'LaMastra P',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['R 0630-0900pm'],
#   'Title': 'Adv Programm & Data Structures'},
#  {'CRN': '75307',
#   'CatalogID': 'SW0304',
#   'Credits': '3',
#   'Instructor': 'Rusu A',
#   'Section': 'A',
#   'Tags': ['SerL'],
#   'Timecodes': ['T 1100-0130pm'],
#   'Title': 'Web Development'},
#  {'CRN': '75207',
#   'CatalogID': 'SW0355',
#   'Credits': '3',
#   'Instructor': 'Corcoran J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0630-0900pm'],
#   'Title': 'Database Management Systems'},
#  {'CRN': '76734',
#   'CatalogID': 'SW0380',
#   'Credits': '3',
#   'Instructor': 'Guelakis W',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['W 0200-0430pm'],
#   'Title': 'Health Information Systems'},
#  {'CRN': '75818',
#   'CatalogID': 'SW0382C',
#   'Credits': '3',
#   'Instructor': 'Govindaraja B',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['M 0630-0900pm'],
#   'Title': 'SpTopics: Android Applications'},
#  {'CRN': '75213',
#   'CatalogID': 'NS0110',
#   'Credits': '3',
#   'Instructor': 'O̥Shea E',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0800-0915am'],
#   'Title': 'Intro Professional Nursing'},
#  {'CRN': '75214',
#   'CatalogID': 'NS0112',
#   'Credits': '3',
#   'Instructor': 'Planas J',
#   'Section': 'A',
#   'Tags': ['USDiv', 'SerL'],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'HealthcareDeliverySystems'},
#  {'CRN': '76536',
#   'CatalogID': 'NS0112',
#   'Credits': '3',
#   'Instructor': 'Murphy M',
#   'Section': 'B',
#   'Tags': ['USDiv', 'SerL'],
#   'Timecodes': ['MR 1100-1215pm'],
#   'Title': 'Healthcare Delivery Systems'},
#  {'CRN': '75252',
#   'CatalogID': 'NS0250',
#   'Credits': '3',
#   'Instructor': 'Pomarico C',
#   'Section': 'A',
#   'Tags': ['USDiv', 'RNNU'],
#   'Timecodes': ['T 0530-0800pm'],
#   'Title': 'Professional Nursing for RN̥s'},
#  {'CRN': '75577',
#   'CatalogID': 'NS0272',
#   'Credits': '4',
#   'Instructor': 'Kris A',
#   'Section': 'A',
#   'Tags': ['ResColl'],
#   'Timecodes': ['MR 1230-0145pm'],
#   'Title': 'Geriatric Nursing'},
#  {'CRN': '75606',
#   'CatalogID': 'NS0272C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0700-0200pm'],
#   'Title': 'Geriatric Nursing Clinical'},
#  {'CRN': '75609',
#   'CatalogID': 'NS0272C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['F 0700-0200pm'],
#   'Title': 'Geriatric Nursing Clinical'},
#  {'CRN': '75615',
#   'CatalogID': 'NS0272C',
#   'Credits': '0',
#   'Instructor': 'Saracino K',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['F 0700-0200pm'],
#   'Title': 'Geriatric Nursing Clinical'},
#  {'CRN': '75616',
#   'CatalogID': 'NS0272C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['W 0700-0200pm'],
#   'Title': 'Geriatric Nursing Clinical'},
#  {'CRN': '76738',
#   'CatalogID': 'NS0272C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['T 0700-0200pm'],
#   'Title': 'Geriatric Nursing Clinical'},
#  {'CRN': '75215',
#   'CatalogID': 'NS0301',
#   'Credits': '4',
#   'Instructor': 'Planas J',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['MR 0200-0315pm'],
#   'Title': 'Health and Wellness'},
#  {'CRN': '76739',
#   'CatalogID': 'NS0301',
#   'Credits': '4',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['MR 0330-0445pm'],
#   'Title': 'Health and Wellness'},
#  {'CRN': '75823',
#   'CatalogID': 'NS0301',
#   'Credits': '4',
#   'Instructor': 'Lovanio K',
#   'Section': 'S',
#   'Tags': ['SDNU'],
#   'Timecodes': ['TF 0200-0500pm'],
#   'Title': 'Health and Wellness'},
#  {'CRN': '75648',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'A',
#   'Tags': [],
#   'Timecodes': ['T 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  {'CRN': '75649',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'B',
#   'Tags': [],
#   'Timecodes': ['F 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  {'CRN': '75651',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'Saracino K',
#   'Section': 'C',
#   'Tags': [],
#   'Timecodes': ['W 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  {'CRN': '75652',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'D',
#   'Tags': [],
#   'Timecodes': ['F 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  {'CRN': '75654',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'E',
#   'Tags': [],
#   'Timecodes': ['W 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  {'CRN': '75656',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'F',
#   'Tags': [],
#   'Timecodes': ['F 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  {'CRN': '75658',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'G',
#   'Tags': [],
#   'Timecodes': ['T 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  {'CRN': '75659',
#   'CatalogID': 'NS0301C',
#   'Credits': '0',
#   'Instructor': 'STAFF',
#   'Section': 'H',
#   'Tags': [],
#   'Timecodes': ['W 0800-0300pm'],
#   'Title': 'Health and Wellness Clinical'},
#  ...]

# %% [markdown]
# To get an idea of how the data looks like as a single denormalized table, we'll use Pandas's built-in JSON formatting library.

# %%
# DO NOT EDIT THIS CELL
from pandas.io.json import json_normalize
json_normalize(course_specs).set_index('CRN')
# Out:
#       CatalogID Credits       Instructor Section  \
# CRN
# 76407    AS0200       3         Bayers P       A
# 76513    AS0400       3         Garvey J      01
# 76934    AS0488       3         Bayers P      01
# 76935  ASEN0490       3          Lopez E      01
# 75478    AY0010       3           Lacy S     C01
# 75479    AY0010       3           Lacy S     C02
# 75752    AY0052       3       Crawford D       A
# 76300    AY0052       3         Wilson J       B
# 75297    AY0110       3         Wilson J       A
# 75728    AY0111       3       Crawford D       A
# 76753    AY0111       3        Wessler S       B
# 76758    AY0115       3        Aronsen G       A
# 76303    AY0152       3       Crawford D       A
# 76754    AY0168       3        Wessler S       A
# 75333    AE0262       3         Liftig R       A
# 75233    AE0265       3         Liftig R       A
# 75282    AE0276       3            Day R       A
# 76234    AE0281       3         Butler B       A
# 76826    AE0284       3          Brown D       A
# 75125    AE0284       3          Brown D       B
# 75001    AE0285       3            STAFF       A
# 75002    AE0291       3        Schmidt D       A
# 75003    AE0291       3  Sticca-Conrod L       B
# 75070    AE0291       3  Sticca-Conrod L       C
# 75308    AE0291       3      Ventrella S       D
# 75313    AE0291       3          Yoder J       E
# 76827    AE0291       3        Schmidt N       F
# 76828    AE0291       3        Schmidt D       G
# 75344    AR0110       3          Douda A       A
# 75402    AR0210       3          Douda A       A
# ...         ...     ...              ...     ...
# 75839   NS0312C       0            STAFF       E
# 76062   NS0312C       0            STAFF       F
# 75384    NS0314       4      LoGiudice J       A
# 75630   NS0314C       0       Manister N       A
# 75631   NS0314C       0       Manister N       B
# 75632   NS0314C       0        Burrows K       C
# 75709   NS0314C       0            STAFF       D
# 76751   NS0314C       0      LoGiudice J       E
# 75237    NS0323       4        O̥Shea E       A
# 75633   NS0323C       0          Roney L       A
# 75634   NS0323C       0            STAFF       B
# 75635   NS0323C       0            STAFF       C
# 75636   NS0323C       0            STAFF       D
# 75637   NS0323C       0            STAFF       E
# 75832   NS0323C       0            STAFF       F
# 75833   NS0323C       0          Roney L       G
# 75238    NS0325       5        Chaplik S       A
# 75239    NS0325       5         Sumpio C       B
# 75638   NS0325C       0   Iannino-Renz R       A
# 75639   NS0325C       0   Iannino-Renz R       B
# 75640   NS0325C       0            STAFF       C
# 75641   NS0325C       0         Bartos S       D
# 75642   NS0325C       0            STAFF       E
# 75643   NS0325C       0            STAFF       F
# 75644   NS0325C       0            STAFF       G
# 75645   NS0325C       0            STAFF       H
# 75396    NS0330       4          Mager D       A
# 75676   NS0330C       0            STAFF       A
# 75678   NS0330C       0            STAFF       B
# 76752   NS0330C       0            STAFF       C
#
#                                 Tags         Timecodes  \
# CRN
# 76407                             []  [MR 0930-1045am]
# 76513                [By Permission]   [W 0630-0830pm]
# 76934                [By Permission]   [M 0630-0830pm]
# 76935                [By Permission]   [T 0545-0745pm]
# 75478                  [CRNST, WDiv]  [TF 1230-0145pm]
# 75479                  [CRNST, WDiv]  [TF 1100-1215pm]
# 75752                             []  [TR 0630-0745pm]
# 76300                             []  [MR 0930-1045am]
# 75297                             []   [M 0630-0900pm]
# 75728                         [WDiv]  [MR 1230-0145pm]
# 76753                         [WDiv]  [TF 0200-0315pm]
# 76758                             []   [T 0630-0900pm]
# 76303                [WDiv, ResColl]  [MR 0930-1045am]
# 76754                         [WDiv]  [TF 0330-0445pm]
# 75333                        [USDiv]   [W 0200-0430pm]
# 75233                        [USDiv]  [TR 0500-0615pm]
# 75282                         [WDiv]  [MR 0930-1045am]
# 76234                             []   [T 0630-0900pm]
# 76826                             []  [WF 0800-0915am]
# 75125                             []   [R 0630-0900pm]
# 75001                             []  [MW 0500-0615pm]
# 75002                             []  [MR 0800-0915am]
# 75003                             []          [Online]
# 75070                             []          [Online]
# 75308                             []   [T 0630-0900pm]
# 75313                             []   [W 0630-0900pm]
# 76827                             []   [W 1100-0130pm]
# 76828                             []   [M 0630-0900pm]
# 75344                             []  [MW 0300-0445pm]
# 75402                             []  [MW 0500-0645pm]
# ...                              ...               ...
# 75839                         [SDNU]   [W 1230-0730pm]
# 76062                         [SDNU]   [R 0100-0800pm]
# 75384                             []  [MR 0930-1045am]
# 75630                             []   [T 0700-0100pm]
# 75631                             []   [W 0700-0100pm]
# 75632                             []   [W 0700-0100pm]
# 75709                             []   [F 0700-0100pm]
# 76751                             []   [T 0700-0100pm]
# 75237                         [SerL]  [MR 0200-0315pm]
# 75633                             []   [T 0700-0100pm]
# 75634                             []   [T 0700-0100pm]
# 75635                             []   [W 0700-0100pm]
# 75636                             []   [W 0700-0100pm]
# 75637                             []   [T 0700-0100pm]
# 75832                             []   [T 0700-0100pm]
# 75833                             []   [T 0700-0100pm]
# 75238                             []  [MR 0330-0445pm]
# 75239                             []  [MR 1230-0145pm]
# 75638                             []   [T 0100-0800pm]
# 75639                             []   [W 0700-0200pm]
# 75640                             []   [W 0700-0200pm]
# 75641                             []   [W 0700-0200pm]
# 75642                             []   [F 0700-0200pm]
# 75643                             []   [F 0700-0200pm]
# 75644                             []   [T 0700-0200pm]
# 75645                             []   [T 0700-0200pm]
# 75396                   [WDiv, RNNU]   [W 0530-0800pm]
# 75676                   [SerL, RNNU]   [W 0800-0430pm]
# 75678  [SerL, RNNU, Nicaragua, Jan.]   [W 0800-0430pm]
# 76752                   [SerL, RNNU]   [W 0800-0430pm]
#
#                                 Title
# CRN
# 76407       Roots of American Culture
# 76513    Critical Issues/Amer Studies
# 76934    Frontier in American Culture
# 76935    Contemporary American Memoir
# 75478    Intro to Four-Field Anthropo
# 75479    Intro to Four-Field Anthropo
# 75752   Culture and Political Economy
# 76300   Culture and Political Economy
# 75297         Biological Anthropology
# 75728           Cultural Anthropology
# 76753           Cultural Anthropology
# 76758         Biomedical Anthropology
# 76303    Islamic Societies & Cultures
# 76754   Women & Men: Anthro of Gender
# 75333        Ethics and the Community
# 75233             Ethics in Education
# 75282  Ethical DimensGlobal BusPolicy
# 76234        Ethics of Communications
# 76826            Environmental Ethics
# 75125            Environmental Ethics
# 75001           Ethics of Health Care
# 75002                 Business Ethics
# 75003                 Business Ethics
# 75070                 Business Ethics
# 75308                 Business Ethics
# 75313                 Business Ethics
# 76827                 Business Ethics
# 76828                 Business Ethics
# 75344             Elementary Arabic I
# 75402           Intermediate Arabic I
# ...                               ...
# 75839  Medl Surgical Nursing I Clinic
# 76062  Medl Surgical Nursing I Clinic
# 75384    Maternal and Newborn Nursing
# 75630   Maternal/Newborn Nursing Clin
# 75631   Maternal/Newborn Nursing Clin
# 75632   Maternal/Newborn Nursing Clin
# 75709   Maternal/Newborn Nursing Clin
# 76751   Maternal/Newborn Nursing Clin
# 75237               Pediatric Nursing
# 75633      Pediatric Nursing Clinical
# 75634      Pediatric Nursing Clinical
# 75635      Pediatric Nursing Clinical
# 75636      Pediatric Nursing Clinical
# 75637      Pediatric Nursing Clinical
# 75832      Pediatric Nursing Clinical
# 75833      Pediatric Nursing Clinical
# 75238     Medical Surgical Nursing II
# 75239     Medical Surgical Nursing II
# 75638  Med Surgical Nursing II Clinic
# 75639  Med Surgical Nursing II Clinic
# 75640  Med Surgical Nursing II Clinic
# 75641  Med Surgical Nursing II Clinic
# 75642  Med Surgical Nursing II Clinic
# 75643  Med Surgical Nursing II Clinic
# 75644  Med Surgical Nursing II Clinic
# 75645  Med Surgical Nursing II Clinic
# 75396   Comm,Pub & Globl Hlth Nursing
# 75676     CommPub&GlblHlthNsCllinical
# 75678     CommPub&GlblHlthNsCllinical
# 76752     CommPub&GlblHlthNsCllinical
#
# [1070 rows x 7 columns]

# %% [markdown]
# Based on your interpretation of the data, **write out the table schema** in **TABLENAME(<u>PK</u>, Attributes, *FK*)** notation. Each PK should be underlined. Each FK should be italics, and the other columns should be plain text. Please list one table per line.
#
# Hints:
# * To see how to underline and italicize in Markdown, just double-click this cell. <!-- You can mix HTML in with Markdown, so underlining is just a <u>...</u> element. -->
# * To force text to appear on a new line you can either use two spaces at the end of the line above<!-- or use an HTML `<br>` tag -->.
# * You can answer this question with just four tables.
# * Two sections with the same CatalogID can have different titles (e.g., for EN11), so treat the titles as section-specific.
# * Credits are specified in the course catalog. They are sometimes are given as a range (e.g., 1-3) instead of as integers, so you may want to use a string.
# * Items in the table above that look like lists **are** lists and need to handled as such.
# * There is a reason why `CRN` was chosen as the index to the DataFrame.
# * Since the only data you have for each faculty member is a name, just treat the instructor names as value objects.
# * You may add surrogate keys if you like, but it's not strictly necessary if you use composite keys.

# %% [markdown]
# **Catalog( Credits, *CatalogID*)**
# **Sections( Section, TimeCodes, *CRN*)**
# **ClassTags( Section, Tags, CRN)**
# **Courses( Instructor, Section, Title, CRN, *CatalogID*)**

# %% [markdown]
# ## 5. (8 points) Write DDL to create your tables (with keys) in the database.
# Suggestions:
# * Use `%%sql` so you can do this on one cell.
# * Use DROP TABLE IF EXISTS for each table before creating it. You've seen this done in a couple of demos so far.

# %%
# %%sql
# DROP TABLE IF EXISTS Catalog;
#
# CREATE TABLE Catalog (
#     Credits TEXT NOT NULL,
#     CatalogID TEXT NOT NULL,
#     FOREIGN KEY (CatalogID) REFERENCES Courses (CatalogID)
# );
#
# DROP TABLE IF EXISTS Sections;
#
# CREATE TABLE Sections (
#     Section TEXT NOT NULL,
#     TimeCodes TEXT NOT NULL,
#     CRN INTEGER NOT NULL,
#     FOREIGN KEY (CRN) REFERENCES ClassTags (CRN)
# );
#
# DROP TABLE IF EXISTS ClassTags;
#
# CREATE TABLE ClassTags (
#     Section TEXT NOT NULL,
#     Tags TEXT NOT NULL,
#     CRN INTEGER NOT NULL
# );
#
# DROP TABLE IF EXISTS Courses;
#
# CREATE TABLE Courses (
#     Instructor TEXT NOT NULL,
#     Section TEXT NOT NULL,
#     Title TEXT NOT NULL,
#     CRN INTEGER NOT NULL,
#     CatalogID TEXT NOT NULL,
#     FOREIGN KEY (CRN) REFERENCES ClassTags (CRN)
# );
# Out:
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %% [markdown]
# ## 4. (up to 8 points) Assemble the data into lists of dicts.
# Each table in your design is a list. Each record in the table is then a dictionary, with the column names as the keys.
#
# There are two approaches you can take:
# 1. (4 points) Construct the lists (and nested dictionaries) by hand. Each list needs to have at least 5 records and cannot violate referential integrity rules.
# 2. (8 points) Extract the data by [Traversing](https://en.wikipedia.org/wiki/Tree_traversal) the `course_specs` tree. Here's a bit of pseudocode for the basic logic:
#
# ```
# initialize an empty set for each table in your design
# for each dict or list at level 1 of the course_specs tree:
#     add records (one or more dicts) to relevant sets
#     note values that represent PKs
#     for each dict or list found at level 2:
#         add records (one or more dicts) to relevant sets
#         note values that represent PKs
#         for each dict or list found at level 3:
#             ...
# ```
# Traversal Notes:
# * With each level you still have access to data in the level above. That allows you to set FKs as needed.
# * The easiest way to add `a_dict` to `a_list` is with `a_list += [a_dict]`.
# * Before adding `a_dict` to `a_list` you should make sure it is not already in the list. You can do that with `if a_dict not in a_list: ...`
# * List for strong entities will *tend* to be populated in level 1, children in level 2, grandchildren in level 3, ...

# %%
Catalog = [{'Credits':'3','CatalogID':'AS0200'},{'Credits':'3','CatalogID':'AS0400'},{'Credits':'3','CatalogID':'AS0488'},
           {'Credits':'3','CatalogID':'ASEN0490'},{'Credits':'3','CatalogID':'AY0010'}]

Sections = [{'Section':'A','TimeCodes':'[MR 0930-1045am]','CRN':'76407'},
            {'Section':'01','TimeCodes':'[W 0630-0830pm]','CRN':'76513'},
            {'Section':'01','TimeCodes':'[M 0630-0830pm]','CRN':'76934'},
            {'Section':'01','TimeCodes':'[T 0545-0745pm]','CRN':'76935'},
            {'Section':'C01','TimeCodes':'[TF 1230-0145pm]','CRN':'75478'}]

ClassTags = [{'Section':'A','Tags':'[]','CRN':'76407'},{'Section':'01','Tags':'[By Permission]','CRN':'76513'},
             {'Section':'01','Tags':'[By Permission]','CRN':'76934'}, {'Section':'01','Tags':'[By Permission]','CRN':'76935'},
             {'Section':'C01','Tags':'[CRNST,WDiv]','CRN':'75478'}]

Courses = [{'Instructor':'Bayers P','Section':'A','Title':'Roots of American Culture','CatalogID':'AS0200','CRN':'76407'},
           {'Instructor':'Garvey J','Section':'01','Title':'Critical Issues/Amer Studies','CatalogID':'AS0400','CRN':'76513'},
           {'Instructor':'Bayers P','Section':'01','Title':'Frontier in American Culture','CatalogID':'AS0488','CRN':'76934'},
           {'Instructor':'Lopez E','Section':'01','Title':'Contemporary American Memoir','CatalogID':'ASEN0490','CRN':'76935'},
           {'Instructor':'Lacy S','Section':'C01','Title':'Intro to Four-Field Anthropo','CatalogID':'AY0010','CRN':'75478'}]

# %% [markdown]
# ## 5. (4 points)  Convert your lists to DataFrames.
# Again, that's one DataFrame per list of dicts. Name the DataFrames to match the table names. Use One cell per DataFrame and display the table at the bottom of the cell.

# %%
Catalog_df = pd.DataFrame(Catalog)
Catalog_df
# Out:
#   CatalogID Credits
# 0    AS0200       3
# 1    AS0400       3
# 2    AS0488       3
# 3  ASEN0490       3
# 4    AY0010       3

# %%
Sections_df = pd.DataFrame(Sections)
Sections_df
# Out:
#      CRN Section         TimeCodes
# 0  76407       A  [MR 0930-1045am]
# 1  76513      01   [W 0630-0830pm]
# 2  76934      01   [M 0630-0830pm]
# 3  76935      01   [T 0545-0745pm]
# 4  75478     C01  [TF 1230-0145pm]

# %%
ClassTags_df = pd.DataFrame(ClassTags)
ClassTags_df
# Out:
#      CRN Section             Tags
# 0  76407       A               []
# 1  76513      01  [By Permission]
# 2  76934      01  [By Permission]
# 3  76935      01  [By Permission]
# 4  75478     C01     [CRNST,WDiv]

# %%
Courses_df = pd.DataFrame(Courses)
Courses_df
# Out:
#      CRN CatalogID Instructor Section                         Title
# 0  76407    AS0200   Bayers P       A     Roots of American Culture
# 1  76513    AS0400   Garvey J      01  Critical Issues/Amer Studies
# 2  76934    AS0488   Bayers P      01  Frontier in American Culture
# 3  76935  ASEN0490    Lopez E      01  Contemporary American Memoir
# 4  75478    AY0010     Lacy S     C01  Intro to Four-Field Anthropo

# %% [markdown]
# ## 6. (6 points) Write your DataFrames to the database.
# * Use the [DataFrame.to_sql() method](https://pandas.pydata.org/pandas-docs/stable/io.html#sql-queries) to write to the database. You will need to set the `if_exists` and (possibly) the `index` arguments when calling `.to_sql()`.
# * You will also need a sqlite3 connection.
# * A few relevant examples were given towards the end in the SQLite DDL and Migration Demo.
# * Provide a SQL SELECT query that joins your tables.

# %%
# connection to database
conn = sqlite3.connect('FairfieldCoursesFall2017.db')

# Putting the Dataframes made to database
Catalog_df.to_sql('Catalog', conn, if_exists = 'append', index = False)
Sections_df.to_sql('Sections', conn, if_exists = 'append', index = False)
ClassTags_df.to_sql('ClassTags', conn, if_exists = 'append', index = False)
Courses_df.to_sql('Courses', conn, if_exists = 'append', index = False)

# %%
# %%sql
# SELECT *
# JOIN Catalog ON Courses.CatalogID = Catalog.CatalogID
# JOIN Sections ON ClassTags.CRN = Sections.CRN
# JOIN Courses ON ClassTags.CRN = Courses.CRN
# Out:
# (sqlite3.OperationalError) near "JOIN": syntax error [SQL: 'SELECT *\nJOIN Catalog ON Courses.CatalogID = Catalog.CatalogID\nJOIN Sections ON ClassTags.CRN = Sections.CRN\nJOIN Courses ON ClassTags.CRN = Courses.CRN']

# %% [markdown]
# ## 7. (1 point) Turn your work to GitHub.
# Commit your work in Git, then push your changes to GitHub.
